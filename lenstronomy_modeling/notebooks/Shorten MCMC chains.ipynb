# %% [markdown]
# In this notebook, we thin the MCMC chains to creat shorter model posterior samples to perform the kinematic computation on. We keep 10,000 samples from each model setup.

# %% [markdown]
# ### import libraries

# %%
import numpy as np
import os
import pickle
import copy
import time
import h5py
from pprint import pprint
import joblib

import lenstronomy.Util.util as util
from lenstronomy.Workflow.fitting_sequence import FittingSequence
from lenstronomy.Plots.model_plot import ModelPlot
from lenstronomy.Plots import chain_plot
from lenstronomy.Sampling.parameters import Param
#from lenstronomy.Analysis.lens_analysis import LensAnalysis
from lenstronomy.Util import mask_util
from lenstronomy.Data.coord_transforms import Coordinates
from lenstronomy.Util.util import array2image

cwd = os.getcwd()
base_path, _ = os.path.split(cwd)
print('Base directory path:', base_path)
# Out:
# Base directory path: /Users/ajshajib/Research/time_delay_cosmography/J2038

# %% [markdown]
# ## output analysis

# %%
# load the custom likelihood function, required for unpickling the moel output
def custom_loglikelihood_addition(kwargs_lens=None, kwargs_source=None, 
                                 kwargs_lens_light=None, kwargs_ps=None, 
                                 kwargs_special=None, kwargs_extinction=None):
    """
    Impose a Gaussian prior on the NFW scale radius R_s based on Gavazzi et al. (2007).
    """
    if kwargs_lens[0]['alpha_Rs'] < 0.:
        return -np.inf
    
    if not -0.014271818911080656-0.2 < kwargs_lens[0]['center_x'] < -0.014271818911080656+0.2:
        return -np.inf
    if not -0.020882886550870693-0.2 < kwargs_lens[0]['center_y'] < -0.020882886550870693+0.2:
        return -np.inf
    
    if not -0.5 < kwargs_lens[0]['e1'] < 0.5:
        return -np.inf
    if not -0.5 < kwargs_lens[0]['e2'] < 0.5:
        return -np.inf
            
    return 0.

# %%
ssh_command = 'ajshajib@hoffman2.idre.ucla.edu'
dir_path = os.getcwd()
dir_path_cluster = '/u/flashscratch/a/ajshajib/'


output_file_list = [
    '2038_run126_0_0_0_0_0',
    '2038_run126_0_0_1_0_0',
    '2038_run126_0_0_2_0_0',
    '2038_run126_0_1_0_0_0',
    '2038_run126_0_1_1_0_0',
    '2038_run126_0_1_2_0_0',
    
    '2038_run126_1_0_0_0_0',
    '2038_run126_1_0_1_0_0',
    '2038_run126_1_0_2_0_0',
    '2038_run126_1_1_0_0_0',
    '2038_run126_1_1_1_0_0',
    '2038_run126_1_1_2_0_0',
]

for job_name_out in output_file_list:
    print("Processing: ", job_name_out)

    hoffman2_out = False
    input_temp = os.path.join(base_path, 'temp', job_name_out +'.txt')
    output_temp = os.path.join(base_path, 'temp', job_name_out +'_out.txt')

    f = open(output_temp, 'rb')
    [input_, output_] = joblib.load(f)
    f.close()
    
    fitting_kwargs_list, multi_band_list, kwargs_model, kwargs_constraints, kwargs_likelihood, kwargs_params, init_samples = input_

    kwargs_result, multi_band_list_out, fit_output, _ = output_

    print('Number of fitting sequence:', len(fit_output))

    print('Number of params:', len(fit_output[-1][2]))

    print("Before trimming...")
    
    for a in range(len(fit_output)):
        print(fit_output[a][0])
        
    for i in range(1):
        del fit_output[-2]

    #for i in range(4):
    #    del fit_output[-3]

    print("After trimming...")
    for a in range(len(fit_output)):
        print(fit_output[a][0])

    samples_mcmc = fit_output[-1][1]

    n_params = samples_mcmc.shape[1]

    n_walkers = 8 * n_params
    n_step = int(samples_mcmc.shape[0] / n_walkers)

    print(n_step, n_walkers, n_params)

    chain = np.empty((n_walkers, n_step, n_params))

    for i in np.arange(n_params):
        samples = samples_mcmc[:, i].T
        chain[:,:,i] = samples.reshape((n_step, n_walkers)).T

    samples_mcmc = chain[-100::10, :, :].reshape((-1, n_params))

    print(samples_mcmc.shape, fit_output[-1][1].shape)

    fit_output[-1][1] = samples_mcmc

    modified_file_path = os.path.join(base_path, 'temp', job_name_out +'_shortened_out.txt')

    input_ = fitting_kwargs_list, multi_band_list, kwargs_model, kwargs_constraints, kwargs_likelihood, kwargs_params, None

    output_ = kwargs_result, multi_band_list_out, fit_output, None

    modified_output = [input_, output_]
    f = open(modified_file_path, 'wb')
    joblib.dump(modified_output, f)
    f.close()
    
    print('\n')
# Out:
# Processing:  2038_run126_0_0_0_0_0
# Number of fitting sequence: 2
# Number of params: 54
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 432 54
# (10000, 54) (432000, 54)
#
#
# Processing:  2038_run126_0_0_1_0_0
# Number of fitting sequence: 2
# Number of params: 54
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 432 54
# (10000, 54) (432000, 54)
#
#
# Processing:  2038_run126_0_0_2_0_0
# Number of fitting sequence: 2
# Number of params: 54
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 432 54
# (10000, 54) (432000, 54)
#
#
# Processing:  2038_run126_0_1_0_0_0
# Number of fitting sequence: 2
# Number of params: 54
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 432 54
# (10000, 54) (432000, 54)
#
#
# Processing:  2038_run126_0_1_1_0_0
# Number of fitting sequence: 2
# Number of params: 54
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 432 54
# (10000, 54) (432000, 54)
#
#
# Processing:  2038_run126_0_1_2_0_0
# Number of fitting sequence: 2
# Number of params: 54
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 432 54
# (10000, 54) (432000, 54)
#
#
# Processing:  2038_run126_1_0_0_0_0
# Number of fitting sequence: 2
# Number of params: 57
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 456 57
# (10000, 57) (456000, 57)
#
#
# Processing:  2038_run126_1_0_1_0_0
# Number of fitting sequence: 2
# Number of params: 57
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 456 57
# (10000, 57) (456000, 57)
#
#
# Processing:  2038_run126_1_0_2_0_0
# Number of fitting sequence: 2
# Number of params: 57
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 456 57
# (10000, 57) (456000, 57)
#
#
# Processing:  2038_run126_1_1_0_0_0
# Number of fitting sequence: 2
# Number of params: 57
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 456 57
# (10000, 57) (456000, 57)
#
#
# Processing:  2038_run126_1_1_1_0_0
# Number of fitting sequence: 2
# Number of params: 57
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 456 57
# (10000, 57) (456000, 57)
#
#
# Processing:  2038_run126_1_1_2_0_0
# Number of fitting sequence: 2
# Number of params: 57
# Before trimming...
# EMCEE
# EMCEE
# After trimming...
# EMCEE
# 1000 456 57
# (10000, 57) (456000, 57)
